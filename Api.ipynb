# %%
import pandas as pd

import requests

# %%
response=requests.get("https://api.themoviedb.org/3/movie/popular?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=10").json()

# %%
popularity=[]
vote_count=[]
original_language=[]
title=[]
vote_average=[]
overview=[]
release_date=[]

# %%
for i in response["results"]:
    popularity.append(i["popularity"])
    vote_count.append(i["vote_count"])
    original_language.append(i["original_language"])
    title.append(i["title"])
    vote_average.append(i["vote_average"])
    overview.append(i["overview"])
    release_date.append(i["release_date"])
d={"title":title,"overview":overview,"original_language":original_language,"release_date":"release_date","popularity":popularity,"vote_count":vote_count,"vote_average":vote_average}
df=pd.DataFrame(d)
df
# Out:
#                                       title  \
# 0                                   Borrego
# 1                        One Piece Film Red
# 2       Harry Potter and the Goblet of Fire
# 3                                     Elvis
# 4                                 Indemnity
# 5               Legend - A Dragon Ball Tale
# 6                      The Man from Toronto
# 7                                      Luca
# 8    Fullmetal Alchemist: The Final Alchemy
# 9                               The Roundup
# 10                                   Hustle
# 11  Harry Potter and the Chamber of Secrets
# 12   Resident Evil: Welcome to Raccoon City
# 13              One Punch Man: Road to Hero
# 14                               Studio 666
# 15        Mortal Kombat Legends: Snow Blind
# 16   Harry Potter and the Half-Blood Prince
# 17                 The Matrix Resurrections
# 18                  Where the Crawdads Sing
# 19                                Toy Story
#
#                                              overview original_language  \
# 0   A young botanist relocates to a small desert t...                en
# 1   Uta — the most beloved singer in the world. He...                ja
# 2   When Harry Potter's name emerges from the Gobl...                en
# 3   The life story of Elvis Presley as seen throug...                en
# 4   An ex-fireman with PTSD goes on the run when a...                en
# 5   Given diplomatic orders by the Grand Council, ...                en
# 6   In a case of mistaken identity, the world’s de...                en
# 7   Luca and his best friend Alberto experience an...                en
# 8   The Elric brothers’ long and winding journey c...                ja
# 9   The ‘Beast Cop’ Ma Seok-do heads to a foreign ...                ko
# 10  After discovering a once-in-a-lifetime player ...                en
# 11  Cars fly, trees fight back, and a mysterious h...                en
# 12  Once the booming home of pharmaceutical giant ...                en
# 13  Defeating numerous villains in the abandoned a...                ja
# 14  Legendary rock band Foo Fighters move into an ...                en
# 15  Hellbent on taking over Earthrealm, Kano vicio...                en
# 16  As Lord Voldemort tightens his grip on both th...                en
# 17  Plagued by strange memories, Neo's life takes ...                en
# 18  Abandoned by her family, Kya raises herself al...                en
# 19  Led by Woody, Andy's toys live happily in his ...                en
#
#     release_date  popularity  vote_count  vote_average
# 0   release_date     247.102          48           6.0
# 1   release_date     263.005          94           7.5
# 2   release_date     230.759       17746           7.8
# 3   release_date     239.110        1600           7.8
# 4   release_date     256.911          68           7.1
# 5   release_date     225.913          25           6.0
# 6   release_date     243.742         778           6.6
# 7   release_date     220.393        6716           7.9
# 8   release_date     407.498          27           6.9
# 9   release_date     252.417          72           7.3
# 10  release_date     236.857        1616           7.9
# 11  release_date     231.445       18761           7.7
# 12  release_date     245.215        1827           6.1
# 13  release_date     231.390         142           8.0
# 14  release_date     228.174         105           6.3
# 15  release_date     402.002           0           0.0
# 16  release_date     230.871       16624           7.7
# 17  release_date     231.847        4160           6.6
# 18  release_date     283.477         418           7.7
# 19  release_date     243.487       15857           8.0

# %%
final=pd.DataFrame()
for j in range(1,41):
    response=requests.get("https://api.themoviedb.org/3/movie/popular?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}".format(j)).json()
    popularity=[]
    vote_count=[]
    original_language=[]
    title=[]
    vote_average=[]
    overview=[]
    release_date=[]
    for i in response["results"]:
        
        popularity.append(i["popularity"])
        vote_count.append(i["vote_count"])
        original_language.append(i["original_language"])
        title.append(i["title"])
        vote_average.append(i["vote_average"])
        overview.append(i["overview"])
        release_date.append(i["release_date"])
    d={"title":title,"overview":overview,"original_language":original_language,"release_date":"release_date","popularity":popularity,"vote_count":vote_count,"vote_average":vote_average}
    df=pd.DataFrame(d)
    final=final.append(df,ignore_index=True)

# %%
final
# Out:
#                                title  \
# 0                 Orphan: First Kill
# 1                       Bullet Train
# 2                               Fall
# 3                   After Ever Happy
# 4                              Beast
# ..                               ...
# 795                  The Incredibles
# 796        Major Grom: Plague Doctor
# 797  Honk for Jesus. Save Your Soul.
# 798                  Shrek the Third
# 799                          Aladdin
#
#                                               overview original_language  \
# 0    After escaping from an Estonian psychiatric fa...                en
# 1    Unlucky assassin Ladybug is determined to do h...                en
# 2    For best friends Becky and Hunter, life is all...                en
# 3    As a shocking truth about a couple's families ...                en
# 4    A recently widowed man and his two teenage dau...                en
# ..                                                 ...               ...
# 795  Bob Parr has given up his superhero days to lo...                en
# 796  Igor Grom is a skilled policeman from St. Pete...                ru
# 797  In the aftermath of a huge scandal, Trinitie C...                en
# 798  The King of Far Far Away has died and Shrek an...                en
# 799  A kindhearted street urchin named Aladdin emba...                en
#
#      release_date  popularity  vote_count  vote_average
# 0    release_date    6183.482         835           6.9
# 1    release_date    6494.330        1304           7.5
# 2    release_date    5308.195        1185           7.5
# 3    release_date    3224.219         237           6.8
# 4    release_date    2693.807         555           7.1
# ..            ...         ...         ...           ...
# 795  release_date      96.087       15574           7.7
# 796  release_date      88.790         464           6.7
# 797  release_date     107.037          10           5.6
# 798  release_date      99.640        7604           6.3
# 799  release_date      98.087        8827           7.1
#
# [800 rows x 7 columns]
