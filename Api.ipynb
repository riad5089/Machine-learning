# %%
import pandas as pd

import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]

# %%
df.head()
# Out:
#                                         title  \
# 0                                        Cars
# 1  Deathstroke: Knights & Dragons - The Movie
# 2                             Kung Fu Panda 3
# 3                                      Bubble
# 4                                 Pacific Rim
#
#                                             overview original_language  \
# 0  Lightning McQueen, a hotshot rookie race car d...                en
# 1  The assassin Deathstroke tries to save his fam...                en
# 2  Continuing his "legendary adventures of awesom...                en
# 3  In an abandoned Tokyo overrun by bubbles and g...                ja
# 4  As war between humankind and monstrous sea cre...                en
#
#    release_date  popularity  vote_count  vote_average
# 0  release_date      67.526       12302           6.9
# 1  release_date      66.398         379           6.9
# 2  release_date      67.361        5011           6.9
# 3  release_date      74.898         296           7.5
# 4  release_date      67.256       11110           6.9

# %%
df = pd.DataFrame()

# %%
df
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = df.append(temp_df,ignore_index=True)

# %%
df
# Out:
#           id                                     title  \
# 0     995133  The Boy, the Mole, the Fox and the Horse
# 1        238                             The Godfather
# 2        278                  The Shawshank Redemption
# 3        240                     The Godfather Part II
# 4        424                          Schindler's List
# ...      ...                                       ...
# 8555  209112        Batman v Superman: Dawn of Justice
# 8556   87516                                    Oldboy
# 8557   19840                   I Love You, Beth Cooper
# 8558   10023                                   Dragnet
# 8559    9988                                  Beerfest
#
#                                                overview release_date  \
# 0     The unlikely friendship of a boy, a mole, a fo...   2022-12-25
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     Framed in the 1940s for the double murder of h...   1994-09-23
# 3     In the continuing saga of the Corleone crime f...   1974-12-20
# 4     The true story of how businessman Oskar Schind...   1993-12-15
# ...                                                 ...          ...
# 8555  Fearing the actions of a god-like Super Hero l...   2016-03-23
# 8556  An everyday man has only three and a half days...   2013-11-14
# 8557  A valedictorian's declaration of love for a hi...   2009-07-10
# 8558  LAPD Sgt. Joe Friday -- the equally straight-l...   1987-06-23
# 8559  During a trip to Germany to scatter their gran...   2006-08-25
#
#       popularity  vote_average  vote_count
# 0         28.858           8.7         205
# 1         88.334           8.7       17435
# 2        111.799           8.7       23246
# 3         47.723           8.6       10557
# 4         44.329           8.6       13732
# ...          ...           ...         ...
# 8555      64.888           5.9       16488
# 8556      16.103           5.9        1722
# 8557      22.860           5.9         749
# 8558       8.803           5.9         386
# 8559       7.776           5.9         453
#
# [8560 rows x 7 columns]

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')

# %%
popularity=[]
vote_count=[]
original_language=[]
title=[]
vote_average=[]
overview=[]
release_date=[]

# %%
for i in response["results"]:
    popularity.append(i["popularity"])
    vote_count.append(i["vote_count"])
    original_language.append(i["original_language"])
    title.append(i["title"])
    vote_average.append(i["vote_average"])
    overview.append(i["overview"])
    release_date.append(i["release_date"])
d={"title":title,"overview":overview,"original_language":original_language,"release_date":"release_date","popularity":popularity,"vote_count":vote_count,"vote_average":vote_average}
df=pd.DataFrame(d)
df
# Out:
#                                            title  \
# 0                  Beauty Salon: Special Service
# 1                                  Hocus Pocus 2
# 2                                   Emancipation
# 3                    Venom: Let There Be Carnage
# 4                                          Venus
# 5                                  Hacksaw Ridge
# 6         The Conjuring: The Devil Made Me Do It
# 7                                        Whisper
# 8              Everything Everywhere All at Once
# 9                              The Next 365 Days
# 10  Harry Potter and the Deathly Hallows: Part 2
# 11                           L'oubliée d'Amboise
# 12                             To Kill the Beast
# 13                                  Interstellar
# 14                                       Jethica
# 15                            Fifty Shades Freed
# 16                                        Fast X
# 17                                 The Lost City
# 18              Transformers: Rise of the Beasts
# 19                           The Price of Family
#
#                                              overview original_language  \
# 0   A legendary beauty salon that is sure to becom...                ko
# 1   29 years since the Black Flame Candle was last...                en
# 2   Inspired by the gripping true story of a man w...                en
# 3   After finding a host body in investigative rep...                en
# 4   Lucía, a club dancer on the run, takes refuge ...                es
# 5   WWII American Army Medic Desmond T. Doss, who ...                en
# 6   Paranormal investigators Ed and Lorraine Warre...                en
# 7   A young Nurse is assigned to look after a pati...                en
# 8   An aging Chinese immigrant is swept up in an i...                en
# 9   Laura and Massimo's relationship hangs in the ...                pl
# 10  Harry, Ron and Hermione continue their quest t...                en
# 11  A violinist is found dead not far from the tom...                fr
# 12  Emilia arrives at her Aunt Inés' hostel locate...                es
# 13  The adventures of a group of explorers who mak...                en
# 14  While hiding out in New Mexico after a freak a...                en
# 15  Believing they have left behind shadowy figure...                en
# 16            The tenth installment in the Fast Saga.                en
# 17  Reclusive author Loretta Sage writes about exo...                en
# 18  A ‘90s globetrotting adventure that introduces...                en
# 19  Heartbroken that their children no longer want...                it
#
#     release_date  popularity  vote_count  vote_average
# 0   release_date     146.167          11           6.2
# 1   release_date     153.538        1309           7.5
# 2   release_date     157.874         747           8.1
# 3   release_date     160.474        8490           6.9
# 4   release_date     163.096          22           6.1
# 5   release_date     167.812       11891           8.2
# 6   release_date     155.619        4923           7.6
# 7   release_date     154.440          52           6.5
# 8   release_date     155.786        3036           8.0
# 9   release_date     140.886         680           6.6
# 10  release_date     158.402       18320           8.1
# 11  release_date     152.520          16           6.3
# 12  release_date     148.040         111           6.0
# 13  release_date     157.405       30475           8.4
# 14  release_date     148.595           5           4.8
# 15  release_date     168.677        7184           6.7
# 16  release_date     155.895           0           0.0
# 17  release_date     138.996        2536           6.7
# 18  release_date     154.731           0           0.0
# 19  release_date     147.300         143           6.6

# %%
# final=pd.DataFrame()
# for j in range(1,41):
#     response=requests.get("https://api.themoviedb.org/3/movie/popular?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}".format(j)).json()
#     popularity=[]
#     vote_count=[]
#     original_language=[]
#     title=[]
#     vote_average=[]
#     overview=[]
#     release_date=[]
#     for i in response["results"]:
        
#         popularity.append(i["popularity"])
#         vote_count.append(i["vote_count"])
#         original_language.append(i["original_language"])
#         title.append(i["title"])
#         vote_average.append(i["vote_average"])
#         overview.append(i["overview"])
#         release_date.append(i["release_date"])
#     d={"title":title,"overview":overview,"original_language":original_language,"release_date":"release_date","popularity":popularity,"vote_count":vote_count,"vote_average":vote_average}
#     df=pd.DataFrame(d)
#     final=final.append(df,ignore_index=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Users\ABDURR~1\AppData\Local\Temp/ipykernel_12340/1133308210.py in <cell line: 2>()
#      17         vote_average.append(i["vote_average"])
#      18         overview.append(i["overview"])
# ---> 19         release_date.append(i["release_date"])
#      20     d={"title":title,"overview":overview,"original_language":original_language,"release_date":"release_date","popularity":popularity,"vote_count":vote_count,"vote_average":vote_average}
#      21     df=pd.DataFrame(d)
#
# KeyError: 'release_date'

# %%
final

# %%
! pip install tmdbv3api

# %%
from tmdbv3api import TMDb
from tmdbv3api import Movie

tmdb = TMDb()
tmdb.api_key = '8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=10'
movie = Movie()

results = movie.search('Inception')
for result in results:
    print(result.title)
    print(result.overview)
