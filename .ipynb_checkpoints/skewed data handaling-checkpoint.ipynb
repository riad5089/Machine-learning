# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=sns.load_dataset("titanic")

# %%
df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df=df[["age","fare","survived"]]

# %%
df.head()
# Out:
#     age     fare  survived
# 0  22.0   7.2500         0
# 1  38.0  71.2833         1
# 2  26.0   7.9250         1
# 3  35.0  53.1000         1
# 4  35.0   8.0500         0

# %%
df.isna().sum()
# Out:
# age         177
# fare          0
# survived      0
# dtype: int64

# %%
df["age"]=df["age"].interpolate()
# Out:
# C:\Users\ABDURR~1\AppData\Local\Temp/ipykernel_13380/2182024646.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["age"]=df["age"].interpolate()

# %%
df.head()
# Out:
#     age     fare  survived
# 0  22.0   7.2500         0
# 1  38.0  71.2833         1
# 2  26.0   7.9250         1
# 3  35.0  53.1000         1
# 4  35.0   8.0500         0

# %%
df.isna().sum()
# Out:
# age         0
# fare        0
# survived    0
# dtype: int64

# %%
plt.figure(figsize=(15,9))
plt.subplot(1,2,1)
plt.hist(df.age,)
plt.subplot(1,2,2)
stats.probplot(df["age"],dist="norm",plot=plt)
plt.show()

# %%
plt.figure(figsize=(15,9))
plt.subplot(1,2,1)
plt.hist(df.fare)
plt.subplot(1,2,2)
stats.probplot(df["fare"],dist="norm",plot=plt)
plt.show()

# %% [markdown]
# # Logarithmic transformation

# %%
df["log_fare"]=np.log(df["fare"]+1)
# Out:
# C:\Users\ABDURR~1\AppData\Local\Temp/ipykernel_13380/1322184104.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["log_fare"]=np.log(df["fare"]+1)

# %%
df.head()
# Out:
#     age     fare  survived  log_fare
# 0  22.0   7.2500         0  2.110213
# 1  38.0  71.2833         1  4.280593
# 2  26.0   7.9250         1  2.188856
# 3  35.0  53.1000         1  3.990834
# 4  35.0   8.0500         0  2.202765

# %%
plt.figure(figsize=(15,9))
plt.subplot(1,2,1)
plt.hist(df.log_fare)
plt.subplot(1,2,2)
stats.probplot(df["log_fare"],dist="norm",plot=plt)
plt.show()

# %% [markdown]
# # reciprocal transformation

# %%
df["rec_fare"]=1/(df.fare+1)
# Out:
# C:\Users\ABDURR~1\AppData\Local\Temp/ipykernel_13380/919992769.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["rec_fare"]=1/(df.fare+1)

# %%
plt.figure(figsize=(15,9))
plt.subplot(1,2,1)
plt.hist(df.rec_fare)
plt.subplot(1,2,2)
stats.probplot(df["rec_fare"],dist="norm",plot=plt)
plt.show()

# %% [markdown]
# # sqare root transformation

# %%
df["sqr_fare"]=np.sqrt(df["fare"])
# Out:
# C:\Users\ABDURR~1\AppData\Local\Temp/ipykernel_13380/3258979807.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["sqr_fare"]=np.sqrt(df["fare"])

# %%
plt.figure(figsize=(15,9))
plt.subplot(1,2,1)
plt.hist(df.sqr_fare)
plt.subplot(1,2,2)
stats.probplot(df["sqr_fare"],dist="norm",plot=plt)
plt.show()

# %% [markdown]
# # Exponential Transformatin

# %%
df["exp_fare"]=df["fare"]**(1/5)

# %%
plt.figure(figsize=(15,9))
plt.subplot(1,2,1)
plt.hist(df.exp_fare)
plt.subplot(1,2,2)
stats.probplot(df["exp_fare"],dist="norm",plot=plt)
plt.show()

# %% [markdown]
# # BoxCox

# %%
df["box_fare"],param=stats.boxcox(df.fare+1)

# %%
plt.figure(figsize=(15,9))
plt.subplot(1,2,1)
plt.hist(df.box_fare)
plt.subplot(1,2,2)
stats.probplot(df["box_fare"],dist="norm",plot=plt)
plt.show()
